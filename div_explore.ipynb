# %%
import pandas as pd
import yfinance as yf

# %%
tickers = ["XOM","VZ","JNJ","CMCSA","MDT","DUK","PNC","KMI","DVN","DOW"]

# %%
data = yf.download(tickers)
# Out:
# [*********************100%%**********************]  10 of 10 completed

# %%
data = data["Close"]

# %%
data.pct_change().cumsum().plot()
# Out:
# <Axes: xlabel='Date'>
